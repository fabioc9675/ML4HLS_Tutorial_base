# %% [markdown]
# # Red Neuronal para discriminacion de Gamma/Neutron
#
# Se creara una red neuronal que discrimine entre Gamma y Neutrones a partir de sus trazas de evento, esto a traves de Machine Learning implementado en la FPGA
#
# *Código adaptado por:* Fabian Castaño
#
# ---
#
# ## Entrenamiento
# Este entrenamiento se realizará basado en el trabajo previo:
# - Workflow based on R. S. Molina, I. R. Morales, M. L. Crespo, V. G. Costa, S. Carrato and G. Ramponi, "An End-to-End Workflow to Efficiently Compress and Deploy DNN Classifiers on SoC/FPGA", in IEEE Embedded Systems Letters, vol. 16, no. 3, pp. 255-258, Sept. 2024, doi: 10.1109/LES.2023.3343030.
# - Code adapted from the official repository of "An End-to-End Workflow to Efficiently Compress and Deploy DNN Classifiers on SoC/FPGA"
# - Using open dataset from: https://doi.org/10.5281/zenodo.8037058

# %% [markdown]
# ![MachineLearning](images/steps_ML.png)

# %% [markdown]
# ### Librerias

# %%
import os
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# Tensorflow and Keras imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l2, l1

import tensorflow_model_optimization as tfmot

# Pruning API
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_schedule, pruning_callbacks
from tensorflow_model_optimization.sparsity.keras import strip_pruning

# Quantization API
from qkeras import *

# Knowledge Distillation
from src.distillationClassKeras import *

# Metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import shuffle

# Pre-processing
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder

# Training utils
from sklearn.model_selection import train_test_split

tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# ### Funciones auxiliares
#
# Definicion de funciones auxiliares para el preprocesamiento del dataset y separacion del set de datos en entrenamiento y test

# %%
# Function to define the training and testing datasets

def preproc_dataset(signal_dfN, signal_dfG,
                    train_size=9000,
                    test_size=1000,
                    seed=42):

    LABEL = "class"

    # shuffle reproducible
    signal_dfN = shuffle(signal_dfN, random_state=seed)
    signal_dfG = shuffle(signal_dfG, random_state=seed)

    # seleccionar tamaños iguales
    train_neutron = signal_dfN.iloc[:train_size]
    test_neutron  = signal_dfN.iloc[train_size:train_size+test_size]

    train_gamma = signal_dfG.iloc[:train_size]
    test_gamma  = signal_dfG.iloc[train_size:train_size+test_size]

    # combinar
    dfTrain = pd.concat([train_neutron, train_gamma])
    dfTest  = pd.concat([test_neutron, test_gamma])

    # mezclar final
    dfTrain = shuffle(dfTrain, random_state=seed).reset_index(drop=True)
    dfTest  = shuffle(dfTest, random_state=seed).reset_index(drop=True)

    # ---------- NORMALIZACION (CRITICO PARA HLS) ----------

    features = dfTrain.columns[:-1]

    dfTrain[features] = dfTrain[features] / 512.0
    dfTest[features]  = dfTest[features] / 512.0

    return dfTrain, dfTest

# %% [markdown]
# ## Dataset
#
# Aqui se carga y se construye el dataset

# %%
# Define paths
PATH = "dataset/"

TRAIN_DATASET_FILE = PATH + "train_dataset.csv"
TEST_DATASET_FILE  = PATH + "test_dataset.csv"

# Load datasets
dfTrain = pd.read_csv(TRAIN_DATASET_FILE)
dfTestGN = pd.read_csv(TEST_DATASET_FILE)

# Separate classes
dfGamma = dfTrain[dfTrain["class"] == 0]
dfNeutron = dfTrain[dfTrain["class"] == 1]

# %% [markdown]
# ### Preprocesamiento y separacion de dataset
#
# Separacion del dataset en datos de entrenamiento y de test

# %%
# Pre-processing dataset for training
df_train, dfTest = preproc_dataset(dfNeutron, dfGamma)

df_train_ = df_train.pop('class')
dfTest_   = dfTest.pop('class')

# One-hot encoder
le = LabelEncoder()
y = le.fit_transform(df_train_)
y = to_categorical(y, 2)

le = LabelEncoder()
yTest = le.fit_transform(dfTest_)
yTest = to_categorical(yTest, 2)

# Split training dataset into training and validation
x_train, x_val, y_train, y_val = train_test_split(df_train, y, test_size=0.3, random_state=42)

x_train = x_train.astype(np.float32)
x_val   = x_val.astype(np.float32)

# %% [markdown]
# ## Machine learning - Training and compression
#
# **Poda (Pruning)**:
# Es una técnica para reducir el tamaño y la complejidad de un modelo eliminando pesos o neuronas que no aportan mucho. Su objetivo es hacerlo más eficiente, con menor uso de memoria y mayor velocidad de inferencia, sin perder demasiada precisión.
#
# **Cuantización (Quantization)**:
# Consiste en bajar la precisión numérica de los parámetros (por ejemplo, de 32 bits a 16 u 8 bits). Esto reduce el tamaño del modelo y acelera la inferencia, especialmente útil en dispositivos con recursos limitados como móviles o microcontroladores.
#
# **Entrenamiento con reconocimiento de cuantización (QAT)**:
# Es una técnica de entrenamiento donde el modelo aprende a adaptarse a la cuantización antes de desplegarse en hardware. En lugar de entrenarlo en precisión completa (32 bits) y después cuantizarlo, la cuantización se introduce durante el entrenamiento.
#
# **Poda con reconocimiento de cuantización (QAP)**:
# Combina la poda (eliminación de conexiones innecesarias en la red) con el entrenamiento consciente de la cuantización. El objetivo es reducir el tamaño del modelo antes de cuantizarlo para obtener una red más eficiente sin perder precisión.
#
# ---

# %% [markdown]
# ### Destilación de conocimiento
#
# Para obtener el modelo reducido que se desplegará en la FPGA (denominado en adelante estudiante), se empleará el enfoque de aprendizaje llamado **destilación de conocimiento (knowledge distillation, KD)**. Este método consiste en que un modelo maestro (teacher) transfiere su conocimiento al modelo estudiante, de forma que este último aprende a imitar el comportamiento del primero, pero con menor complejidad.
#
# Para más información sobre KD:
# Hinton, G. (2015). Distilling the Knowledge in a Neural Network. arXiv preprint arXiv:1503.02531.

# %% [markdown]
# ## Entrenamiento del Teacher

# %%
# Define the hyperparameters for the teacher model

lr = 0.0001
neurons_teacher = [10, 5, 7, 5, 6]

# %% [markdown]
# La siguiente funcion define la arquitectura del **teacher** compuesto por seis capas densas, *bestHP* contiene el numero de neuronas por cada capa densa

# %% [markdown]
# ![Teacher Model](images/teacherArchitecture_.png)

# %%
def teacher_topology(bestHp):

    teacher = keras.Sequential(
        [
            keras.Input(shape=(161, )),
            Dense(bestHp[0], name='fc1', input_shape=(161,), kernel_regularizer=l2(0.001),),
            Activation(activation='relu', name='relu1'),

            Dense(bestHp[1], name='fc2', kernel_regularizer=l2(0.001),),
            Activation(activation='relu', name='relu2'),

            Dense(bestHp[2], name='fc3', kernel_regularizer=l2(0.001),),
            Activation(activation='relu', name='relu3'),
            Dropout(0.1),

            Dense(bestHp[3], name='fc4', kernel_regularizer=l2(0.001),),
            Activation(activation='relu', name='relu4'),
            Dropout(0.2),

            Dense(bestHp[4], name='fc5'),
            Activation(activation='relu', name='relu5'),
            Dropout(0.2),

            Dense(2, name='output'),
            Activation('softmax', name='activationOutput'),
            # Activation(activation='sigmoid', name='activationOutput'),
        ],
        name='teacher_MLP',
    )

    teacher.summary()

    return teacher

# %% [markdown]
# ### Construccion del modelo Teacher
#
# Esta función define la topología del modelo maestro llamando a la función ´teacher_topology()´, configura el optimizador **Adam** con la tasa de aprendizaje correspondiente y establece la configuración del modelo utilizando binary_crossentropy como función de pérdida y accuracy como métrica de evaluación.

# %%
def build_teacher(neurons_teacher):
    model = teacher_topology(neurons_teacher)
    opt = Adam(lr)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
teacher_model = build_teacher(neurons_teacher)
# Out:
# Model: "teacher_MLP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc1 (Dense)                 (None, 10)                1620
#
#  relu1 (Activation)          (None, 10)                0
#
#  fc2 (Dense)                 (None, 5)                 55
#
#  relu2 (Activation)          (None, 5)                 0
#
#  fc3 (Dense)                 (None, 7)                 42
#
#  relu3 (Activation)          (None, 7)                 0
#
#  dropout (Dropout)           (None, 7)                 0
#
#  fc4 (Dense)                 (None, 5)                 40
#
#  relu4 (Activation)          (None, 5)                 0
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  fc5 (Dense)                 (None, 6)                 36
#
#  relu5 (Activation)          (None, 6)                 0
#
#  dropout_2 (Dropout)         (None, 6)                 0
#
#  output (Dense)              (None, 2)                 14
#
#  activationOutput (Activatio  (None, 2)                0
#  n)
#
# =================================================================
# Total params: 1,807
# Trainable params: 1,807
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training
#
# Entrenamiento del modelo teacher

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=2,
        verbose=1,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.4,
        patience=3,
        verbose=1
    )
]

history_teacher = teacher_model.fit(
    x=x_train, y=y_train,
    validation_data=(x_val, y_val),
    batch_size=64,
    epochs=200,
    callbacks=callbacks,   
    verbose=1
)
# Out:
# Epoch 1/200
# 197/197 [==============================] - 1s 2ms/step - loss: 0.7281 - accuracy: 0.5264 - val_loss: 0.7199 - val_accuracy: 0.5046 - lr: 1.0000e-04
# Epoch 2/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.7128 - accuracy: 0.5571 - val_loss: 0.6964 - val_accuracy: 0.5046 - lr: 1.0000e-04
# Epoch 3/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.6835 - accuracy: 0.5735 - val_loss: 0.6475 - val_accuracy: 0.5046 - lr: 1.0000e-04
# Epoch 4/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.6403 - accuracy: 0.6200 - val_loss: 0.5802 - val_accuracy: 0.8911 - lr: 1.0000e-04
# Epoch 5/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.5940 - accuracy: 0.7390 - val_loss: 0.5210 - val_accuracy: 0.9496 - lr: 1.0000e-04
# Epoch 6/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.5655 - accuracy: 0.7663 - val_loss: 0.4785 - val_accuracy: 0.9598 - lr: 1.0000e-04
# Epoch 7/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.5361 - accuracy: 0.7760 - val_loss: 0.4524 - val_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 8/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.5183 - accuracy: 0.7987 - val_loss: 0.4246 - val_accuracy: 0.9731 - lr: 1.0000e-04
# Epoch 9/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.8498 - val_loss: 0.4031 - val_accuracy: 0.9781 - lr: 1.0000e-04
# Epoch 10/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4863 - accuracy: 0.8592 - val_loss: 0.3838 - val_accuracy: 0.9787 - lr: 1.0000e-04
# Epoch 11/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4747 - accuracy: 0.8676 - val_loss: 0.3700 - val_accuracy: 0.9813 - lr: 1.0000e-04
# Epoch 12/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.8716 - val_loss: 0.3591 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 13/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.8842 - val_loss: 0.3507 - val_accuracy: 0.9854 - lr: 1.0000e-04
# Epoch 14/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4446 - accuracy: 0.8855 - val_loss: 0.3407 - val_accuracy: 0.9848 - lr: 1.0000e-04
# Epoch 15/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4338 - accuracy: 0.8970 - val_loss: 0.3336 - val_accuracy: 0.9856 - lr: 1.0000e-04
# Epoch 16/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8989 - val_loss: 0.3287 - val_accuracy: 0.9880 - lr: 1.0000e-04
# Epoch 17/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.9125 - val_loss: 0.3203 - val_accuracy: 0.9865 - lr: 1.0000e-04
# Epoch 18/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.9279 - val_loss: 0.3148 - val_accuracy: 0.9874 - lr: 1.0000e-04
# Epoch 19/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.9330 - val_loss: 0.3095 - val_accuracy: 0.9865 - lr: 1.0000e-04
# Epoch 20/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.9433 - val_loss: 0.3043 - val_accuracy: 0.9878 - lr: 1.0000e-04
# Epoch 21/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.9431 - val_loss: 0.2995 - val_accuracy: 0.9880 - lr: 1.0000e-04
# Epoch 22/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3811 - accuracy: 0.9506 - val_loss: 0.2956 - val_accuracy: 0.9876 - lr: 1.0000e-04
# Epoch 23/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.9525 - val_loss: 0.2906 - val_accuracy: 0.9887 - lr: 1.0000e-04
# Epoch 24/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.9507 - val_loss: 0.2871 - val_accuracy: 0.9880 - lr: 1.0000e-04
# Epoch 25/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3615 - accuracy: 0.9527 - val_loss: 0.2827 - val_accuracy: 0.9887 - lr: 1.0000e-04
# Epoch 26/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3542 - accuracy: 0.9614 - val_loss: 0.2796 - val_accuracy: 0.9880 - lr: 1.0000e-04
# Epoch 27/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.3490 - accuracy: 0.9631 - val_loss: 0.2746 - val_accuracy: 0.9906 - lr: 1.0000e-04
# Epoch 28/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.9630 - val_loss: 0.2731 - val_accuracy: 0.9881 - lr: 1.0000e-04
# Epoch 29/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.9663 - val_loss: 0.2673 - val_accuracy: 0.9913 - lr: 1.0000e-04
# Epoch 30/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3263 - accuracy: 0.9660 - val_loss: 0.2644 - val_accuracy: 0.9900 - lr: 1.0000e-04
# Epoch 31/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3108 - accuracy: 0.9706 - val_loss: 0.2609 - val_accuracy: 0.9907 - lr: 1.0000e-04
# Epoch 32/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3041 - accuracy: 0.9766 - val_loss: 0.2594 - val_accuracy: 0.9893 - lr: 1.0000e-04
# Epoch 33/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.3030 - accuracy: 0.9735 - val_loss: 0.2568 - val_accuracy: 0.9891 - lr: 1.0000e-04
# Epoch 34/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2953 - accuracy: 0.9770 - val_loss: 0.2509 - val_accuracy: 0.9911 - lr: 1.0000e-04
# Epoch 35/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2893 - accuracy: 0.9756 - val_loss: 0.2487 - val_accuracy: 0.9907 - lr: 1.0000e-04
# Epoch 36/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.9783 - val_loss: 0.2483 - val_accuracy: 0.9900 - lr: 1.0000e-04
# Epoch 37/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2694 - accuracy: 0.9814 - val_loss: 0.2427 - val_accuracy: 0.9911 - lr: 1.0000e-04
# Epoch 38/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2689 - accuracy: 0.9810 - val_loss: 0.2392 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 39/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2654 - accuracy: 0.9820 - val_loss: 0.2371 - val_accuracy: 0.9913 - lr: 1.0000e-04
# Epoch 40/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2576 - accuracy: 0.9833 - val_loss: 0.2340 - val_accuracy: 0.9913 - lr: 1.0000e-04
# Epoch 41/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2568 - accuracy: 0.9845 - val_loss: 0.2313 - val_accuracy: 0.9915 - lr: 1.0000e-04
# Epoch 42/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.9857 - val_loss: 0.2290 - val_accuracy: 0.9913 - lr: 1.0000e-04
# Epoch 43/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2462 - accuracy: 0.9846 - val_loss: 0.2266 - val_accuracy: 0.9911 - lr: 1.0000e-04
# Epoch 44/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2487 - accuracy: 0.9855 - val_loss: 0.2220 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 45/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2434 - accuracy: 0.9847 - val_loss: 0.2187 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 46/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2351 - accuracy: 0.9855 - val_loss: 0.2159 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 47/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2308 - accuracy: 0.9854 - val_loss: 0.2139 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 48/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9860 - val_loss: 0.2123 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 49/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2314 - accuracy: 0.9860 - val_loss: 0.2086 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 50/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2250 - accuracy: 0.9843 - val_loss: 0.2063 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 51/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2214 - accuracy: 0.9861 - val_loss: 0.2048 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 52/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2186 - accuracy: 0.9865 - val_loss: 0.2013 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 53/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2142 - accuracy: 0.9864 - val_loss: 0.1984 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 54/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2144 - accuracy: 0.9853 - val_loss: 0.1957 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 55/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2097 - accuracy: 0.9867 - val_loss: 0.1933 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 56/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.9844 - val_loss: 0.1915 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 57/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2078 - accuracy: 0.9870 - val_loss: 0.1888 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 58/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.2044 - accuracy: 0.9862 - val_loss: 0.1864 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 59/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2020 - accuracy: 0.9876 - val_loss: 0.1844 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 60/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.2009 - accuracy: 0.9860 - val_loss: 0.1829 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 61/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1942 - accuracy: 0.9871 - val_loss: 0.1800 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 62/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1965 - accuracy: 0.9875 - val_loss: 0.1776 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 63/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1911 - accuracy: 0.9877 - val_loss: 0.1755 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 64/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1869 - accuracy: 0.9875 - val_loss: 0.1749 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 65/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1886 - accuracy: 0.9871 - val_loss: 0.1736 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 66/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1856 - accuracy: 0.9872 - val_loss: 0.1694 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 67/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1805 - accuracy: 0.9871 - val_loss: 0.1686 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 68/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1796 - accuracy: 0.9881 - val_loss: 0.1657 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 69/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1782 - accuracy: 0.9874 - val_loss: 0.1647 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 70/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1748 - accuracy: 0.9879 - val_loss: 0.1628 - val_accuracy: 0.9922 - lr: 1.0000e-04
# Epoch 71/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1756 - accuracy: 0.9875 - val_loss: 0.1597 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 72/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1701 - accuracy: 0.9878 - val_loss: 0.1579 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 73/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1727 - accuracy: 0.9861 - val_loss: 0.1569 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 74/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1699 - accuracy: 0.9883 - val_loss: 0.1538 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 75/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1675 - accuracy: 0.9875 - val_loss: 0.1524 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 76/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9868 - val_loss: 0.1508 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 77/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1641 - accuracy: 0.9887 - val_loss: 0.1493 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 78/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1596 - accuracy: 0.9879 - val_loss: 0.1473 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 79/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1596 - accuracy: 0.9871 - val_loss: 0.1466 - val_accuracy: 0.9922 - lr: 1.0000e-04
# Epoch 80/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1588 - accuracy: 0.9875 - val_loss: 0.1440 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 81/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1591 - accuracy: 0.9875 - val_loss: 0.1426 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 82/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1568 - accuracy: 0.9873 - val_loss: 0.1415 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 83/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9866 - val_loss: 0.1392 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 84/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1485 - accuracy: 0.9863 - val_loss: 0.1386 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 85/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1484 - accuracy: 0.9877 - val_loss: 0.1376 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 86/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1511 - accuracy: 0.9876 - val_loss: 0.1359 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 87/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1472 - accuracy: 0.9863 - val_loss: 0.1338 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 88/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1474 - accuracy: 0.9861 - val_loss: 0.1319 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 89/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1431 - accuracy: 0.9874 - val_loss: 0.1305 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 90/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9884 - val_loss: 0.1294 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 91/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1395 - accuracy: 0.9873 - val_loss: 0.1284 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 92/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1416 - accuracy: 0.9871 - val_loss: 0.1278 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 93/200
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1375 - accuracy: 0.9894 - val_loss: 0.1251 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 94/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1342 - accuracy: 0.9875 - val_loss: 0.1249 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 95/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1323 - accuracy: 0.9887 - val_loss: 0.1233 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 96/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1304 - accuracy: 0.9881 - val_loss: 0.1234 - val_accuracy: 0.9926 - lr: 1.0000e-04
# Epoch 97/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1297 - accuracy: 0.9873 - val_loss: 0.1203 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 98/200
# 197/197 [==============================] - 0s 1ms/step - loss: 0.1294 - accuracy: 0.9879 - val_loss: 0.1206 - val_accuracy: 0.9922 - lr: 1.0000e-04
# Epoch 99/200
# 186/197 [===========================>..] - ETA: 0s - loss: 0.1242 - accuracy: 0.9882Restoring model weights from the end of the best epoch: 97.
# 197/197 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9883 - val_loss: 0.1216 - val_accuracy: 0.9920 - lr: 1.0000e-04
# Epoch 99: early stopping

# %% [markdown]
# ### Plot accuracy and loss
#
# Plots el comportamiento de la exactitud y la perdida durante el entrenamiento.

# %%
print(history_teacher.history.keys())

## Plot for accuracy
plt.figure(figsize=(15,3))
plt.plot(history_teacher.history['accuracy'])
plt.plot(history_teacher.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
plt.figure()

## Plot for loss
plt.figure(figsize=(15,3))
plt.plot(history_teacher.history['loss'])
plt.plot(history_teacher.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# Hasta aqui ya se logró un entrenamiento satisfactorio de la red neuronal
#
# ---

# %% [markdown]
# ## Analisis del rendimiento
#
# Medimos el rendimiento mediante la matriz de confusion

# %%
# Obtain the confusion matrix using the testing dataset 
y_pred_probs = teacher_model.predict(dfTest)
y_pred = np.argmax(y_pred_probs, axis=1)

# Since y_test is one-hot encoded, you need to convert it back to class indices
y_true = np.argmax(yTest, axis=1)  # Convert one-hot encoded labels to class indices

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
#plt.figure(figsize=(6, 6))
plt.title('Confusion Matrix - Teacher model')
plt.show()
# Out:
# 60/60 [==============================] - 0s 670us/step

# %% [markdown]
# ### Guardado del modelo Teacher

# %%
# If needed, save the teacher model [uncomment the following line]
teacher_model.save('models/teacherModel_GN_GICM.h5')

# %% [markdown]
# ---
# **Autor**: Fabian Castaño
